# %% [markdown]
# <a href="https://colab.research.google.com/github/joaovctrr/cadastro/blob/main/ler_pdf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tabula-py

# %%
import tabula
import pandas as pd
import os
import re

# %%
pdf = tabula.read_pdf('/content/2024-020024940.pdf', pages = 'all')
# Out:
# WARNING:tabula.backend:Got stderr: Jun 14, 2024 6:56:46 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Symbol
# Jun 14, 2024 6:56:46 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font ZapfDingbats

# %%
pdf
# Out:
# [Empty DataFrame
#  Columns: [SISTEMA INTEGRADO DE SEGURANCA PÚBLICA -  POLICIA MILITAR, 2
#  No 2024-020024940-001]
#  Index: [],
#                                             Unnamed: 0  \
#  0                                                 NaN
#  1     UNIDADE RESPONSÁVEL PELO REGISTRO\rBPTRAN/1 RPM
#  2                  DATA DO REGISTRO\r02/05/2024 09:33
#  3                  2\rDADOS DA OCORRÊNCIA / ATIVIDADE
#  4   PROVÁVEL DESCRIÇÃO DA OCORRÊNCIA PRINCIPAL\rX0...
#  5           ALVO DO EVENTO\rORGAO/SECRETARIA ESTADUAL
#  6                  DATA/HORA DO FATO\r02/05/202409:00
#  7       DESCRIÇÃO DO LUGAR\rORGAO/SECRETARIA ESTADUAL
#  8       LOCAL (AV., RUA, ETC)\rRUA TENENTE BRITO MELO
#  9                                        NÚMERO\r1090
#  10                          MUNICÍPIO\rBELO HORIZONTE
#  11           PONTO DE REFERÊNCIA\rRÁDIO INCONFIDÊNCIA
#  12                                     TIPO VIA\rXXXX
#  13                              CAUSA PRESUMIDA\rXXXX
#  14             2\rHISTÓRICO DA OCORRÊNCIA / ATIVIDADE
#  15  CUMPRIDO DEMANDA ADMINISTRATIVA DA ASSESSORIA ...
#  16                                        2\rVIATURAS
#  17                                          VIATURA 1
#  18                         TIPO DA VIATURA\rPRINCIPAL
#  19       DESCRIÇÃO / OBSERVAÇÃO\rVIATURA UTILITARIO -
#  20                                     PLACA\rRMZ4I02
#  21                 2\rMILITARES/POLICIAIS INTEGRANTES
#  22                        MILITAR/POLICIAL INTEGRANTE
#  23                                     NUM VIATURA\r1
#  24       NOME COMPLETO\rREINALDO CAMPOS DO NASCIMENTO
#  25                        CORPORAÇÃO\rPOLICIA MILITAR
#  26            UNIDADE\r2 PEL/3 CIA PTRAN/BPTRAN/1 RPM
#  27                        MILITAR/POLICIAL INTEGRANTE
#  28                                     NUM VIATURA\r1
#  29               NOME COMPLETO\rEDMILSON LUCIO SOARES
#  30                        CORPORAÇÃO\rPOLICIA MILITAR
#  31            UNIDADE\r1 PEL/3 CIA PTRAN/BPTRAN/1 RPM
#  32                        MILITAR/POLICIAL INTEGRANTE
#  33                                     NUM VIATURA\r1
#  34                 NOME COMPLETO\rBRUNO RIBEIRO PINTO
#  35                        CORPORAÇÃO\rPOLICIA MILITAR
#  36            UNIDADE\r2 PEL/2 CIA PTRAN/BPTRAN/1 RPM
#
#                     BOLETIM DE OCORRÊNCIA SIMPLIFICADO  \
#  0                                                 NaN
#  1                           MUNICÍPIO\rBELO HORIZONTE
#  2                                                 NaN
#  3                                                 NaN
#  4                                                 NaN
#  5                                                 NaN
#  6                 DATA/HORA DO LOCAL\r02/05/202412:00
#  7   COMPL DE LOCAL MEDIATO\rORGAO/SECRETARIA ESTADUAL
#  8                                                 NaN
#  9                                            KM\rXXXX
#  10                                             UF\rMG
#  11                             LATITUDE\r-19o55'37,9"
#  12                                                NaN
#  13                                                NaN
#  14                                                NaN
#  15                                                NaN
#  16                                                NaN
#  17                                                NaN
#  18                             ÓRGÃO\rPOLICIA MILITAR
#  19                                                NaN
#  20                                PREFIXO / ÓRGÃO\rPM
#  21                                                NaN
#  22                                                NaN
#  23                                 MATRÍCULA\r1353796
#  24                                                NaN
#  25                                                NaN
#  26                                   Hipotecado?\rNÃO
#  27                                                NaN
#  28                                 MATRÍCULA\r1387307
#  29                                                NaN
#  30                                                NaN
#  31                                   Hipotecado?\rNÃO
#  32                                                NaN
#  33                                 MATRÍCULA\r1584051
#  34                                                NaN
#  35                                                NaN
#  36                                   Hipotecado?\rNÃO
#
#                                                 Fl.1/2  \
#  0                                                 NaN
#  1                                                 NaN
#  2                                                 NaN
#  3                                                 NaN
#  4                                                 NaN
#  5                                                 NaN
#  6   DATA/HORA FINAL DO PREENCHIMENTO\r09/05/202415:15
#  7                                                 NaN
#  8                                                 NaN
#  9                                   COMPLEMENTO\rXXXX
#  10                                       PAÍS\rBRASIL
#  11                           LONGITUDE\r-43o57'21,29"
#  12                                                NaN
#  13                                                NaN
#  14                                                NaN
#  15                                                NaN
#  16                                                NaN
#  17                                                NaN
#  18                                                NaN
#  19                                                NaN
#  20                              REGISTRO GERAL\r30958
#  21                                                NaN
#  22                                                NaN
#  23                                  CARGO\r3 SARGENTO
#  24                                                NaN
#  25                                                NaN
#  26                                                NaN
#  27                                                NaN
#  28                                  CARGO\r3 SARGENTO
#  29                                                NaN
#  30                                                NaN
#  31                                                NaN
#  32                                                NaN
#  33                                        CARGO\rCABO
#  34                                                NaN
#  35                                                NaN
#  36                                                NaN
#
#                      Unnamed: 1                             Unnamed: 2
#  0                          NaN                                    NaN
#  1                          NaN                                    NaN
#  2                          NaN                                    NaN
#  3                          NaN                                    NaN
#  4                          NaN                                    NaN
#  5                          NaN                                    NaN
#  6                          NaN                                    NaN
#  7                          NaN                                    NaN
#  8                          NaN                                    NaN
#  9   BAIRRO / VILA\rBARRO PRETO                              CEP\rXXXX
#  10                         NaN                                    NaN
#  11                         NaN                                    NaN
#  12                         NaN                                    NaN
#  13                         NaN                                    NaN
#  14                         NaN                                    NaN
#  15                         NaN                                    NaN
#  16                         NaN                                    NaN
#  17                         NaN                                    NaN
#  18                         NaN                                    NaN
#  19                         NaN                                    NaN
#  20       PREFIXO PADRÃO\r30958  PROBLEMAS DURANTE O ATENDIMENTO\rXXXX
#  21                         NaN                                    NaN
#  22                         NaN                                    NaN
#  23                         NaN                                    NaN
#  24                         NaN                                    NaN
#  25                         NaN                                    NaN
#  26                         NaN                                    NaN
#  27                         NaN                                    NaN
#  28                         NaN                                    NaN
#  29                         NaN                                    NaN
#  30                         NaN                                    NaN
#  31                         NaN                                    NaN
#  32                         NaN                                    NaN
#  33                         NaN                                    NaN
#  34                         NaN                                    NaN
#  35                         NaN                                    NaN
#  36                         NaN                                    NaN  ,
#    SISTEMA INTEGRADO DE SEGURANCA PÚBLICA -  POLICIA MILITAR  \
#  0                 BOLETIM DE OCORRÊNCIA SIMPLIFICADO
#
#    No 2024-020024940-001
#  0               Fl. 2/2  ]

# %%
print(type(pdf))
# Out:
# <class 'list'>

# %%
df = pdf[2]

# %%
df
# Out:
#   SISTEMA INTEGRADO DE SEGURANCA PÚBLICA -  POLICIA MILITAR  \
# 0                 BOLETIM DE OCORRÊNCIA SIMPLIFICADO
#
#   No 2024-020024940-001
# 0               Fl. 2/2

# %%
df_completo = pd.concat(pdf, ignore_index=False)

# %%
df_completo
# Out:
#    SISTEMA INTEGRADO DE SEGURANCA PÚBLICA -  POLICIA MILITAR  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 0                  BOLETIM DE OCORRÊNCIA SIMPLIFICADO
#
#     2\rNo 2024-020024940-001  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10                       NaN
# 11                       NaN
# 12                       NaN
# 13                       NaN
# 14                       NaN
# 15                       NaN
# 16                       NaN
# 17                       NaN
# 18                       NaN
# 19                       NaN
# 20                       NaN
# 21                       NaN
# 22                       NaN
# 23                       NaN
# 24                       NaN
# 25                       NaN
# 26                       NaN
# 27                       NaN
# 28                       NaN
# 29                       NaN
# 30                       NaN
# 31                       NaN
# 32                       NaN
# 33                       NaN
# 34                       NaN
# 35                       NaN
# 36                       NaN
# 0                        NaN
#
#                                            Unnamed: 0  \
# 0                                                 NaN
# 1     UNIDADE RESPONSÁVEL PELO REGISTRO\rBPTRAN/1 RPM
# 2                  DATA DO REGISTRO\r02/05/2024 09:33
# 3                  2\rDADOS DA OCORRÊNCIA / ATIVIDADE
# 4   PROVÁVEL DESCRIÇÃO DA OCORRÊNCIA PRINCIPAL\rX0...
# 5           ALVO DO EVENTO\rORGAO/SECRETARIA ESTADUAL
# 6                  DATA/HORA DO FATO\r02/05/202409:00
# 7       DESCRIÇÃO DO LUGAR\rORGAO/SECRETARIA ESTADUAL
# 8       LOCAL (AV., RUA, ETC)\rRUA TENENTE BRITO MELO
# 9                                        NÚMERO\r1090
# 10                          MUNICÍPIO\rBELO HORIZONTE
# 11           PONTO DE REFERÊNCIA\rRÁDIO INCONFIDÊNCIA
# 12                                     TIPO VIA\rXXXX
# 13                              CAUSA PRESUMIDA\rXXXX
# 14             2\rHISTÓRICO DA OCORRÊNCIA / ATIVIDADE
# 15  CUMPRIDO DEMANDA ADMINISTRATIVA DA ASSESSORIA ...
# 16                                        2\rVIATURAS
# 17                                          VIATURA 1
# 18                         TIPO DA VIATURA\rPRINCIPAL
# 19       DESCRIÇÃO / OBSERVAÇÃO\rVIATURA UTILITARIO -
# 20                                     PLACA\rRMZ4I02
# 21                 2\rMILITARES/POLICIAIS INTEGRANTES
# 22                        MILITAR/POLICIAL INTEGRANTE
# 23                                     NUM VIATURA\r1
# 24       NOME COMPLETO\rREINALDO CAMPOS DO NASCIMENTO
# 25                        CORPORAÇÃO\rPOLICIA MILITAR
# 26            UNIDADE\r2 PEL/3 CIA PTRAN/BPTRAN/1 RPM
# 27                        MILITAR/POLICIAL INTEGRANTE
# 28                                     NUM VIATURA\r1
# 29               NOME COMPLETO\rEDMILSON LUCIO SOARES
# 30                        CORPORAÇÃO\rPOLICIA MILITAR
# 31            UNIDADE\r1 PEL/3 CIA PTRAN/BPTRAN/1 RPM
# 32                        MILITAR/POLICIAL INTEGRANTE
# 33                                     NUM VIATURA\r1
# 34                 NOME COMPLETO\rBRUNO RIBEIRO PINTO
# 35                        CORPORAÇÃO\rPOLICIA MILITAR
# 36            UNIDADE\r2 PEL/2 CIA PTRAN/BPTRAN/1 RPM
# 0                                                 NaN
#
#                    BOLETIM DE OCORRÊNCIA SIMPLIFICADO  \
# 0                                                 NaN
# 1                           MUNICÍPIO\rBELO HORIZONTE
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                 DATA/HORA DO LOCAL\r02/05/202412:00
# 7   COMPL DE LOCAL MEDIATO\rORGAO/SECRETARIA ESTADUAL
# 8                                                 NaN
# 9                                            KM\rXXXX
# 10                                             UF\rMG
# 11                             LATITUDE\r-19o55'37,9"
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                             ÓRGÃO\rPOLICIA MILITAR
# 19                                                NaN
# 20                                PREFIXO / ÓRGÃO\rPM
# 21                                                NaN
# 22                                                NaN
# 23                                 MATRÍCULA\r1353796
# 24                                                NaN
# 25                                                NaN
# 26                                   Hipotecado?\rNÃO
# 27                                                NaN
# 28                                 MATRÍCULA\r1387307
# 29                                                NaN
# 30                                                NaN
# 31                                   Hipotecado?\rNÃO
# 32                                                NaN
# 33                                 MATRÍCULA\r1584051
# 34                                                NaN
# 35                                                NaN
# 36                                   Hipotecado?\rNÃO
# 0                                                 NaN
#
#                                                Fl.1/2  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   DATA/HORA FINAL DO PREENCHIMENTO\r09/05/202415:15
# 7                                                 NaN
# 8                                                 NaN
# 9                                   COMPLEMENTO\rXXXX
# 10                                       PAÍS\rBRASIL
# 11                           LONGITUDE\r-43o57'21,29"
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                              REGISTRO GERAL\r30958
# 21                                                NaN
# 22                                                NaN
# 23                                  CARGO\r3 SARGENTO
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                  CARGO\r3 SARGENTO
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                        CARGO\rCABO
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 0                                                 NaN
#
#                     Unnamed: 1                             Unnamed: 2  \
# 0                          NaN                                    NaN
# 1                          NaN                                    NaN
# 2                          NaN                                    NaN
# 3                          NaN                                    NaN
# 4                          NaN                                    NaN
# 5                          NaN                                    NaN
# 6                          NaN                                    NaN
# 7                          NaN                                    NaN
# 8                          NaN                                    NaN
# 9   BAIRRO / VILA\rBARRO PRETO                              CEP\rXXXX
# 10                         NaN                                    NaN
# 11                         NaN                                    NaN
# 12                         NaN                                    NaN
# 13                         NaN                                    NaN
# 14                         NaN                                    NaN
# 15                         NaN                                    NaN
# 16                         NaN                                    NaN
# 17                         NaN                                    NaN
# 18                         NaN                                    NaN
# 19                         NaN                                    NaN
# 20       PREFIXO PADRÃO\r30958  PROBLEMAS DURANTE O ATENDIMENTO\rXXXX
# 21                         NaN                                    NaN
# 22                         NaN                                    NaN
# 23                         NaN                                    NaN
# 24                         NaN                                    NaN
# 25                         NaN                                    NaN
# 26                         NaN                                    NaN
# 27                         NaN                                    NaN
# 28                         NaN                                    NaN
# 29                         NaN                                    NaN
# 30                         NaN                                    NaN
# 31                         NaN                                    NaN
# 32                         NaN                                    NaN
# 33                         NaN                                    NaN
# 34                         NaN                                    NaN
# 35                         NaN                                    NaN
# 36                         NaN                                    NaN
# 0                          NaN                                    NaN
#
#    No 2024-020024940-001
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
# 6                    NaN
# 7                    NaN
# 8                    NaN
# 9                    NaN
# 10                   NaN
# 11                   NaN
# 12                   NaN
# 13                   NaN
# 14                   NaN
# 15                   NaN
# 16                   NaN
# 17                   NaN
# 18                   NaN
# 19                   NaN
# 20                   NaN
# 21                   NaN
# 22                   NaN
# 23                   NaN
# 24                   NaN
# 25                   NaN
# 26                   NaN
# 27                   NaN
# 28                   NaN
# 29                   NaN
# 30                   NaN
# 31                   NaN
# 32                   NaN
# 33                   NaN
# 34                   NaN
# 35                   NaN
# 36                   NaN
# 0                Fl. 2/2

# %%
df_completo.columns = df_completo.columns.str.replace('\r', ' ')

for col in df_completo.columns:
    if df_completo[col].dtype == 'object':
        df_completo[col] = df_completo[col].str.replace('\r', ' ')

# %%
df_completo
# Out:
#    SISTEMA INTEGRADO DE SEGURANCA PÚBLICA -  POLICIA MILITAR  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 0                  BOLETIM DE OCORRÊNCIA SIMPLIFICADO
#
#     2 No 2024-020024940-001  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       NaN
# 10                      NaN
# 11                      NaN
# 12                      NaN
# 13                      NaN
# 14                      NaN
# 15                      NaN
# 16                      NaN
# 17                      NaN
# 18                      NaN
# 19                      NaN
# 20                      NaN
# 21                      NaN
# 22                      NaN
# 23                      NaN
# 24                      NaN
# 25                      NaN
# 26                      NaN
# 27                      NaN
# 28                      NaN
# 29                      NaN
# 30                      NaN
# 31                      NaN
# 32                      NaN
# 33                      NaN
# 34                      NaN
# 35                      NaN
# 36                      NaN
# 0                       NaN
#
#                                            Unnamed: 0  \
# 0                                                 NaN
# 1      UNIDADE RESPONSÁVEL PELO REGISTRO BPTRAN/1 RPM
# 2                   DATA DO REGISTRO 02/05/2024 09:33
# 3                   2 DADOS DA OCORRÊNCIA / ATIVIDADE
# 4   PROVÁVEL DESCRIÇÃO DA OCORRÊNCIA PRINCIPAL X03...
# 5            ALVO DO EVENTO ORGAO/SECRETARIA ESTADUAL
# 6                   DATA/HORA DO FATO 02/05/202409:00
# 7        DESCRIÇÃO DO LUGAR ORGAO/SECRETARIA ESTADUAL
# 8        LOCAL (AV., RUA, ETC) RUA TENENTE BRITO MELO
# 9                                         NÚMERO 1090
# 10                           MUNICÍPIO BELO HORIZONTE
# 11            PONTO DE REFERÊNCIA RÁDIO INCONFIDÊNCIA
# 12                                      TIPO VIA XXXX
# 13                               CAUSA PRESUMIDA XXXX
# 14              2 HISTÓRICO DA OCORRÊNCIA / ATIVIDADE
# 15  CUMPRIDO DEMANDA ADMINISTRATIVA DA ASSESSORIA ...
# 16                                         2 VIATURAS
# 17                                          VIATURA 1
# 18                          TIPO DA VIATURA PRINCIPAL
# 19        DESCRIÇÃO / OBSERVAÇÃO VIATURA UTILITARIO -
# 20                                      PLACA RMZ4I02
# 21                  2 MILITARES/POLICIAIS INTEGRANTES
# 22                        MILITAR/POLICIAL INTEGRANTE
# 23                                      NUM VIATURA 1
# 24        NOME COMPLETO REINALDO CAMPOS DO NASCIMENTO
# 25                         CORPORAÇÃO POLICIA MILITAR
# 26             UNIDADE 2 PEL/3 CIA PTRAN/BPTRAN/1 RPM
# 27                        MILITAR/POLICIAL INTEGRANTE
# 28                                      NUM VIATURA 1
# 29                NOME COMPLETO EDMILSON LUCIO SOARES
# 30                         CORPORAÇÃO POLICIA MILITAR
# 31             UNIDADE 1 PEL/3 CIA PTRAN/BPTRAN/1 RPM
# 32                        MILITAR/POLICIAL INTEGRANTE
# 33                                      NUM VIATURA 1
# 34                  NOME COMPLETO BRUNO RIBEIRO PINTO
# 35                         CORPORAÇÃO POLICIA MILITAR
# 36             UNIDADE 2 PEL/2 CIA PTRAN/BPTRAN/1 RPM
# 0                                                 NaN
#
#                   BOLETIM DE OCORRÊNCIA SIMPLIFICADO  \
# 0                                                NaN
# 1                           MUNICÍPIO BELO HORIZONTE
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                 DATA/HORA DO LOCAL 02/05/202412:00
# 7   COMPL DE LOCAL MEDIATO ORGAO/SECRETARIA ESTADUAL
# 8                                                NaN
# 9                                            KM XXXX
# 10                                             UF MG
# 11                             LATITUDE -19o55'37,9"
# 12                                               NaN
# 13                                               NaN
# 14                                               NaN
# 15                                               NaN
# 16                                               NaN
# 17                                               NaN
# 18                             ÓRGÃO POLICIA MILITAR
# 19                                               NaN
# 20                                PREFIXO / ÓRGÃO PM
# 21                                               NaN
# 22                                               NaN
# 23                                 MATRÍCULA 1353796
# 24                                               NaN
# 25                                               NaN
# 26                                   Hipotecado? NÃO
# 27                                               NaN
# 28                                 MATRÍCULA 1387307
# 29                                               NaN
# 30                                               NaN
# 31                                   Hipotecado? NÃO
# 32                                               NaN
# 33                                 MATRÍCULA 1584051
# 34                                               NaN
# 35                                               NaN
# 36                                   Hipotecado? NÃO
# 0                                                NaN
#
#                                               Fl.1/2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6   DATA/HORA FINAL DO PREENCHIMENTO 09/05/202415:15
# 7                                                NaN
# 8                                                NaN
# 9                                   COMPLEMENTO XXXX
# 10                                       PAÍS BRASIL
# 11                           LONGITUDE -43o57'21,29"
# 12                                               NaN
# 13                                               NaN
# 14                                               NaN
# 15                                               NaN
# 16                                               NaN
# 17                                               NaN
# 18                                               NaN
# 19                                               NaN
# 20                              REGISTRO GERAL 30958
# 21                                               NaN
# 22                                               NaN
# 23                                  CARGO 3 SARGENTO
# 24                                               NaN
# 25                                               NaN
# 26                                               NaN
# 27                                               NaN
# 28                                  CARGO 3 SARGENTO
# 29                                               NaN
# 30                                               NaN
# 31                                               NaN
# 32                                               NaN
# 33                                        CARGO CABO
# 34                                               NaN
# 35                                               NaN
# 36                                               NaN
# 0                                                NaN
#
#                    Unnamed: 1                            Unnamed: 2  \
# 0                         NaN                                   NaN
# 1                         NaN                                   NaN
# 2                         NaN                                   NaN
# 3                         NaN                                   NaN
# 4                         NaN                                   NaN
# 5                         NaN                                   NaN
# 6                         NaN                                   NaN
# 7                         NaN                                   NaN
# 8                         NaN                                   NaN
# 9   BAIRRO / VILA BARRO PRETO                              CEP XXXX
# 10                        NaN                                   NaN
# 11                        NaN                                   NaN
# 12                        NaN                                   NaN
# 13                        NaN                                   NaN
# 14                        NaN                                   NaN
# 15                        NaN                                   NaN
# 16                        NaN                                   NaN
# 17                        NaN                                   NaN
# 18                        NaN                                   NaN
# 19                        NaN                                   NaN
# 20       PREFIXO PADRÃO 30958  PROBLEMAS DURANTE O ATENDIMENTO XXXX
# 21                        NaN                                   NaN
# 22                        NaN                                   NaN
# 23                        NaN                                   NaN
# 24                        NaN                                   NaN
# 25                        NaN                                   NaN
# 26                        NaN                                   NaN
# 27                        NaN                                   NaN
# 28                        NaN                                   NaN
# 29                        NaN                                   NaN
# 30                        NaN                                   NaN
# 31                        NaN                                   NaN
# 32                        NaN                                   NaN
# 33                        NaN                                   NaN
# 34                        NaN                                   NaN
# 35                        NaN                                   NaN
# 36                        NaN                                   NaN
# 0                         NaN                                   NaN
#
#    No 2024-020024940-001
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
# 6                    NaN
# 7                    NaN
# 8                    NaN
# 9                    NaN
# 10                   NaN
# 11                   NaN
# 12                   NaN
# 13                   NaN
# 14                   NaN
# 15                   NaN
# 16                   NaN
# 17                   NaN
# 18                   NaN
# 19                   NaN
# 20                   NaN
# 21                   NaN
# 22                   NaN
# 23                   NaN
# 24                   NaN
# 25                   NaN
# 26                   NaN
# 27                   NaN
# 28                   NaN
# 29                   NaN
# 30                   NaN
# 31                   NaN
# 32                   NaN
# 33                   NaN
# 34                   NaN
# 35                   NaN
# 36                   NaN
# 0                Fl. 2/2

# %%
df = df_completo

# %%
print(df['Unnamed: 0'])
# Out:
# 0                                                   NaN
# 1        UNIDADE RESPONSÁVEL PELO REGISTRO BPTRAN/1 RPM
# 2                     DATA DO REGISTRO 02/05/2024 09:33
# 3                     2 DADOS DA OCORRÊNCIA / ATIVIDADE
# 4     PROVÁVEL DESCRIÇÃO DA OCORRÊNCIA PRINCIPAL X03...
# 5              ALVO DO EVENTO ORGAO/SECRETARIA ESTADUAL
# 6                     DATA/HORA DO FATO 02/05/202409:00
# 7          DESCRIÇÃO DO LUGAR ORGAO/SECRETARIA ESTADUAL
# 8          LOCAL (AV., RUA, ETC) RUA TENENTE BRITO MELO
# 9                                           NÚMERO 1090
# 10                             MUNICÍPIO BELO HORIZONTE
# 11              PONTO DE REFERÊNCIA RÁDIO INCONFIDÊNCIA
# 12                                        TIPO VIA XXXX
# 13                                 CAUSA PRESUMIDA XXXX
# 14                2 HISTÓRICO DA OCORRÊNCIA / ATIVIDADE
# 15    CUMPRIDO DEMANDA ADMINISTRATIVA DA ASSESSORIA ...
# 16                                           2 VIATURAS
# 17                                            VIATURA 1
# 18                            TIPO DA VIATURA PRINCIPAL
# 19          DESCRIÇÃO / OBSERVAÇÃO VIATURA UTILITARIO -
# 20                                        PLACA RMZ4I02
# 21                    2 MILITARES/POLICIAIS INTEGRANTES
# 22                          MILITAR/POLICIAL INTEGRANTE
# 23                                        NUM VIATURA 1
# 24          NOME COMPLETO REINALDO CAMPOS DO NASCIMENTO
# 25                           CORPORAÇÃO POLICIA MILITAR
# 26               UNIDADE 2 PEL/3 CIA PTRAN/BPTRAN/1 RPM
# 27                          MILITAR/POLICIAL INTEGRANTE
# 28                                        NUM VIATURA 1
# 29                  NOME COMPLETO EDMILSON LUCIO SOARES
# 30                           CORPORAÇÃO POLICIA MILITAR
# 31               UNIDADE 1 PEL/3 CIA PTRAN/BPTRAN/1 RPM
# 32                          MILITAR/POLICIAL INTEGRANTE
# 33                                        NUM VIATURA 1
# 34                    NOME COMPLETO BRUNO RIBEIRO PINTO
# 35                           CORPORAÇÃO POLICIA MILITAR
# 36               UNIDADE 2 PEL/2 CIA PTRAN/BPTRAN/1 RPM
# 0                                                   NaN
# Name: Unnamed: 0, dtype: object

# %%
df['Unnamed: 0'] = df['Unnamed: 0'].astype(str)

# %%
df['Unnamed: 0']
# Out:
# 0                                                   nan
# 1        UNIDADE RESPONSÁVEL PELO REGISTRO BPTRAN/1 RPM
# 2                     DATA DO REGISTRO 02/05/2024 09:33
# 3                     2 DADOS DA OCORRÊNCIA / ATIVIDADE
# 4     PROVÁVEL DESCRIÇÃO DA OCORRÊNCIA PRINCIPAL X03...
# 5              ALVO DO EVENTO ORGAO/SECRETARIA ESTADUAL
# 6                     DATA/HORA DO FATO 02/05/202409:00
# 7          DESCRIÇÃO DO LUGAR ORGAO/SECRETARIA ESTADUAL
# 8          LOCAL (AV., RUA, ETC) RUA TENENTE BRITO MELO
# 9                                           NÚMERO 1090
# 10                             MUNICÍPIO BELO HORIZONTE
# 11              PONTO DE REFERÊNCIA RÁDIO INCONFIDÊNCIA
# 12                                        TIPO VIA XXXX
# 13                                 CAUSA PRESUMIDA XXXX
# 14                2 HISTÓRICO DA OCORRÊNCIA / ATIVIDADE
# 15    CUMPRIDO DEMANDA ADMINISTRATIVA DA ASSESSORIA ...
# 16                                           2 VIATURAS
# 17                                            VIATURA 1
# 18                            TIPO DA VIATURA PRINCIPAL
# 19          DESCRIÇÃO / OBSERVAÇÃO VIATURA UTILITARIO -
# 20                                        PLACA RMZ4I02
# 21                    2 MILITARES/POLICIAIS INTEGRANTES
# 22                          MILITAR/POLICIAL INTEGRANTE
# 23                                        NUM VIATURA 1
# 24          NOME COMPLETO REINALDO CAMPOS DO NASCIMENTO
# 25                           CORPORAÇÃO POLICIA MILITAR
# 26               UNIDADE 2 PEL/3 CIA PTRAN/BPTRAN/1 RPM
# 27                          MILITAR/POLICIAL INTEGRANTE
# 28                                        NUM VIATURA 1
# 29                  NOME COMPLETO EDMILSON LUCIO SOARES
# 30                           CORPORAÇÃO POLICIA MILITAR
# 31               UNIDADE 1 PEL/3 CIA PTRAN/BPTRAN/1 RPM
# 32                          MILITAR/POLICIAL INTEGRANTE
# 33                                        NUM VIATURA 1
# 34                    NOME COMPLETO BRUNO RIBEIRO PINTO
# 35                           CORPORAÇÃO POLICIA MILITAR
# 36               UNIDADE 2 PEL/2 CIA PTRAN/BPTRAN/1 RPM
# 0                                                   nan
# Name: Unnamed: 0, dtype: object

# %%
dados_capturados
# Out:
#                                        NOME COMPLETO  \
# 0  REINALDO CAMPOS DO NASCIMENTO, EDMILSON LUCIO ...
# 1  RONAN PAULA DE SOUZA JUNIOR, EDMILSON LUCIO SO...
# 2  REINALDO CAMPOS DO NASCIMENTO, RONAN PAULA DE ...
# 3  RONAN PAULA DE SOUZA JUNIOR, EDMILSON LUCIO SO...
# 4  REINALDO CAMPOS DO NASCIMENTO, EDMILSON LUCIO ...
# 5
# 6
#
#                                      LOCAL NÚMERO       MUNICÍPIO  \
# 0                   RUA TENENTE BRITO MELO   1090  BELO HORIZONTE
# 1                        RUA ADELINO TESTI     30  BELO HORIZONTE
# 2                    AVENIDA SENHORA CARMO         BELO HORIZONTE
# 3  RODOVIA PRESIDENTE JUSCELINO KUBITSCHEK     95       NOVA LIMA
# 4                  AVENIDA OLINTO MEIRELES   5000  BELO HORIZONTE
# 5                                              65
# 6
#
#    PONTO DE REFERÊNCIA             DATA HORA
# 0  RÁDIO INCONFIDÊNCIA  02/05/202409:00
# 1                 XXXX  17/05/202413:00
# 2          RADIO 98 FM
# 3                 XXXX
# 4   VALLOUREC BARREIRO
# 5
# 6

# %%
diretorio_pdfs = '.'


nomes_pdfs = []

for filename in os.listdir(diretorio_pdfs):
    if filename.endswith('.pdf'):
        nomes_pdfs.append(os.path.join(diretorio_pdfs, filename))

dfs = []

for pdf_file in nomes_pdfs:
    try:
                df = tabula.read_pdf(pdf_file, pages='all', pandas_options={'header': None})
        dfs.extend(df)
    except Exception as e:
        print(f"Erro ao processar o arquivo {pdf_file}: {str(e)}")

df_final = pd.concat(dfs, ignore_index=True)

# Inicializa listas para armazenar as informações
nomes = []
locais = []
numeros = []
municipios = []
pontos_referencia = []

# Variáveis auxiliares para acompanhar o nome completo e o número atual
nome_atual = ''
numero_atual = ''

# Expressão regular para identificar números de endereço no formato XX ou XXXX (dois ou quatro dígitos)
regex_numero = re.compile(r'\b\d{2,4}\b')

for index, row in df_final.iterrows():
    if isinstance(row[0], str):
        if 'PONTO DE REFERÊNCIA' in row[0]:
            partes = row[0].split('PONTO DE REFERÊNCIA')
            if len(partes) > 1:
                pontos_referencia.append(partes[1].strip())
                if nome_atual:
                    nomes.append(nome_atual.strip())
                nome_atual = ''
        elif 'LOCAL (AV., RUA, ETC)' in row[0]:
            partes = row[0].split('LOCAL (AV., RUA, ETC)')
            if len(partes) > 1:
                locais.append(partes[1].strip())
        elif 'NÚMERO' in row[0]:
            partes = row[0].split('NÚMERO')
            if len(partes) > 1:
                numero = partes[1].strip()
                # Verifica se o número corresponde ao padrão de endereço esperado
                if regex_numero.match(numero):
                    numeros.append(numero)
                    if nome_atual:
                        nomes.append(nome_atual.strip())
                else:
                    numero_atual = numero
                nome_atual = ''
        elif 'MUNICÍPIO' in row[0]:
            partes = row[0].split('MUNICÍPIO')
            if len(partes) > 1:
                municipios.append(partes[1].strip())
        elif 'NOME COMPLETO' in row[0]:
            partes = row[0].split('NOME COMPLETO')
            if len(partes) > 1:
                if nome_atual:
                    nome_atual += ', ' + partes[1].strip()
                else:
                    nome_atual = partes[1].strip()


if nome_atual:
    nomes.append(nome_atual.strip())
    if not numeros:
        numeros.append(numero_atual)

max_length = max(len(nomes), len(locais), len(numeros), len(municipios), len(pontos_referencia))

# Preenche as listas com valores vazios para terem o mesmo comprimento
nomes += [''] * (max_length - len(nomes))
locais += [''] * (max_length - len(locais))
numeros += [''] * (max_length - len(numeros))
municipios += [''] * (max_length - len(municipios))
pontos_referencia += [''] * (max_length - len(pontos_referencia))

# Cria um DataFrame com as informações capturadas
dados_capturados = pd.DataFrame({
    'NOME COMPLETO': nomes,
    'LOCAL': locais,
    'NÚMERO': numeros,
    'MUNICÍPIO': municipios,
    'PONTO DE REFERÊNCIA': pontos_referencia
})

nome_excel = './dados_extraidos.xlsx'

# Salva o DataFrame em um arquivo Excel
dados_capturados.to_excel(nome_excel, index=False, engine='openpyxl')

print(f'Dados salvos com sucesso em {nome_excel}')
# Out:
# WARNING:tabula.backend:Got stderr: Jun 14, 2024 7:21:17 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Symbol
# Jun 14, 2024 7:21:17 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font ZapfDingbats
#
# WARNING:tabula.backend:Got stderr: Jun 14, 2024 7:21:20 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Symbol
# Jun 14, 2024 7:21:20 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font ZapfDingbats
#
# WARNING:tabula.backend:Got stderr: Jun 14, 2024 7:21:23 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Symbol
# Jun 14, 2024 7:21:23 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font ZapfDingbats
#
# WARNING:tabula.backend:Got stderr: Jun 14, 2024 7:21:26 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Symbol
# Jun 14, 2024 7:21:26 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font ZapfDingbats
#
# WARNING:tabula.backend:Got stderr: Jun 14, 2024 7:21:29 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Symbol
# Jun 14, 2024 7:21:29 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font ZapfDingbats
# Dados salvos com sucesso em ./dados_extraidos.xlsx
